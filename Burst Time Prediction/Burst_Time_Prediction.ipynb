# %%
import sklearn 
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#load dataset
process_dataset =  pd.read_csv('process_data.csv')
# Out:
#              1  1136070690     0      11  1.1      4.0    35848.0  1.2  \
# 0            2  1136072890     1      46    1      3.0    49216.0    1
# 1            3  1136074695     1  197831    1      0.0        0.0    1
# 2            4  1136074754     2  197682    1      0.0        0.0    1
# 3            5  1136074756     2  197552    1      0.0        0.0    1
# 4            6  1136074814     1  197495    1      0.0        0.0    1
# 5            7  1136077528    58      -1    0     -1.0       -1.0    1
# 6            8  1136077775    58      -1    0     -1.0       -1.0    1
# 7            9  1136077889    58      -1    0     -1.0       -1.0    1
# 8           10  1136078195    58      -1    0     -1.0       -1.0    1
# 9           11  1136078435    58      -1    0     -1.0       -1.0    1
# 10          12  1136078608    58      -1    0     -1.0       -1.0    1
# 11          13  1136078676   117      -1    0     -1.0       -1.0    1
# ...
